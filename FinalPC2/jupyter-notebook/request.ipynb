# %%
import pymysql 
db = pymysql.connect(host='10.5.0.1', port=32000, user='root', password='root',database='hurtos')
cur = db.cursor(pymysql.cursors.DictCursor)

sql = "select * from hurtos.table_name as tb where tb.SEXO = 'MASCULINO'"
cur.execute(sql)
total=[]
for row in cur:
    total.append(row)

sql = "select * from hurtos.table_name as tb where tb.SEXO = 'FEMENINO'"
cur.execute(sql)
total2=[]
for row in cur:
    total2.append(row)

sql = "select * from hurtos.table_name as tb where tb.ARMA_EMPLEADA = 'SIN EMPLEO DE ARMAS'"
cur.execute(sql)
total3=[]
for row in cur:
    total3.append(row)

sql = "select * from hurtos.table_name as tb where tb.ARMA_EMPLEADA = 'ARMA BLANCA'"
cur.execute(sql)
total4=[]
for row in cur:
    total4.append(row)

sql = "select * from hurtos.table_name as tb where tb.ARMA_EMPLEADA = 'ARMA DE FUEGO'"
cur.execute(sql)
total5=[]
for row in cur:
    total5.append(row)

sql = "select * from hurtos.table_name as tb where tb.ARMA_EMPLEADA = 'CONTUNDENTES'"
cur.execute(sql)
total6=[]
for row in cur:
    total6.append(row)

sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'VEHICULO'"
cur.execute(sql)
total7=[]
for row in cur:
    total7.append(row)

sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'A PIE'"
cur.execute(sql)
total8=[]
for row in cur:
    total8.append(row)

sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'PASAJERO BUS'"
cur.execute(sql)
total9=[]
for row in cur:
    total9.append(row)
    
sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'CONDUCTOR TAXI'"
cur.execute(sql)
total10=[]
for row in cur:
    total10.append(row)

sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'BICICLETA'"
cur.execute(sql)
total11=[]
for row in cur:
    total11.append(row)
    
sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'CONDUCTOR MOTOCICLETA'"
cur.execute(sql)
total12=[]
for row in cur:
    total12.append(row)
    
sql = "select * from hurtos.table_name as tb where tb.MOVIL_AGRESOR = 'PASAJERO MOTOCICLETA'"
cur.execute(sql)
total13=[]
for row in cur:
    total13.append(row)

# %%
import matplotlib.pyplot as plt

names = ['Masculino', 'Femenino']
values = [len(total), len(total2)]

plt.suptitle('No. de hurtos por genero en Bogota')
plt.bar(names, values)
plt.show()

# %%
names = ['Sin arma', 'Arma blanca', 'Arma de fuego', 'Contundentes']
values = [len(total3), len(total4), len(total5), len(total6)]

plt.suptitle('Tipo de arma empleada por el agresor')
plt.bar(names, values)
plt.show()

# %%
names = ['Vehiculo', 'A pie', 'Pasajero bus', 'Conductor taxi', 'Bicicleta', 'Conductor motocicleta', 'Pasajero motocicleta']
values = [len(total7), len(total8), len(total9), len(total10), len(total11), len(total12), len(total13)]

plt.figure(figsize=(15, 4))

plt.suptitle('Vehiculo en el que se transportaba el agresor')
plt.bar(names, values)
plt.show()
